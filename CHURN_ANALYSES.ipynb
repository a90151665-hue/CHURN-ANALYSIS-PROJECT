# %%
from google .colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-131b855c-e64a-4f3f-b0f9-fbf3a37d7566" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-131b855c-e64a-4f3f-b0f9-fbf3a37d7566">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn (9).csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df['TotlCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce').fillna(0)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df['SeniorCitizen']= df['SeniorCitizen'].replace({1: 'Yes', 0: 'No'})

# %%
df.columns = df.columns.str.strip()

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
print(df.isnull().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# TotlCharges         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Churn', data=df, palette='Set2')
plt.title("Churn Distribution")
plt.show()
# Out:
# /tmp/ipython-input-1599469399.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette='Set2')

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='SeniorCitizen', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
we can focus on non senior citizen people , we can give offers for the non citizen people to stay with the company,by giving more offer and promotions.

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Partner', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
df.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
we can focus on un married peoples,by giving more data packs and offers to them they will be satisfied with the company

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Dependents', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
non dependents can be more focused ,we can give more offers to stay with the company and give free entertainments like movies and songs and improvr the customer satisfaction.

# %%
plt.figure(figsize=(10,14))
sns.histplot(x='tenure', data=df,hue='Churn')
plt.xticks(rotation=90)
plt.title("Churn Distribution")
plt.show()

# %%
we can focus on the monthly plans, improve the plan rate and give offers to charge rate on this way we can change the mothly recharging customer to half year or yearly recharges

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='PhoneService', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
we can focus on the

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='MultipleLines', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='OnlineSecurity', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='OnlineBackup', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='DeviceProtection', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='TechSupport', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='StreamingTV', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='StreamingMovies', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Contract', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='PaperlessBilling', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='PaymentMethod', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.boxplot(y='MonthlyCharges', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.boxplot(x='TotalCharges', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Churn', data=df,hue='Churn')
plt.title("Churn Distribution")
plt.show()

# %%
sns.countplot(x='gender', hue='Churn', data=df, palette='Set2')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x='SeniorCitizen', hue='Churn', data=df, palette='Set2')
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %%
plt.show()

# %%
sns.countplot(x='Partner', hue='Churn', data=df, palette='Set2')
# Out:
# <Axes: xlabel='Partner', ylabel='count'>

# %%
sns.countplot(x='Dependents', hue='Churn', data=df, palette='Set2')
plt.title("Dependents vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='PaymentMethod', hue='Churn',data=df, palette='Set2')
plt.title("Pyment Method vs Churn")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='InternetService', hue='Churn', data=df, palette='Set2')
plt.title("Internet Service vs Churn")
plt.show()

# %%
sns.boxplot(x='Churn',y='tenure', data=df, palette='Set2')
plt.title("Tenure vs Churn")
plt.show()
# Out:
# /tmp/ipython-input-2009821027.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn',y='tenure', data=df, palette='Set2')

# %%
sns.boxplot(x='Churn',y='MonthlyCharges', data=df, palette='Set2')
plt.title("Monthly Charges vs Churn")
plt.show()
# Out:
# /tmp/ipython-input-3585559609.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn',y='MonthlyCharges', data=df, palette='Set2')

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Churn_encoded'] = le.fit_transform(df['Churn'])

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  \
# 0  No phone service             DSL             No  ...
# 1                No             DSL            Yes  ...
# 2                No             DSL            Yes  ...
# 3  No phone service             DSL            Yes  ...
# 4                No     Fiber optic             No  ...
#
#   InternetService_encoded OnlineSecurity_encoded TechSupport_encoded  \
# 0                       0                      0                   0
# ...

# %%
df['gender_encoded'] = le.fit_transform(df['gender'])

# %%
df['SeniorCitizen_encoded'] = le.fit_transform(df['SeniorCitizen'])
df['Partner_encoded'] = le.fit_transform(df['Partner'])
df['Dependents_encoded'] = le.fit_transform(df['Dependents'])
df['tenure_encoded'] = le.fit_transform(df['tenure'])
df['PhoneService_encoded'] = le.fit_transform(df['PhoneService'])
df['MultipleLines_encoded'] = le.fit_transform(df['MultipleLines'])
df['InternetService_encoded'] = le.fit_transform(df['InternetService'])
df['OnlineSecurity_encoded'] = le.fit_transform(df['OnlineSecurity'])
df['TechSupport_encoded'] = le.fit_transform(df['TechSupport'])
df['StreamingTV_encoded'] = le.fit_transform(df['StreamingTV'])
df['StreamingMovies_encoded'] = le.fit_transform(df['StreamingMovies'])
df['Contract_encoded'] = le.fit_transform(df['Contract'])
df['PaperlessBilling_encoded'] = le.fit_transform(df['PaperlessBilling'])
df['PaymentMethod_encoded'] = le.fit_transform(df['PaymentMethod'])
df['MonthlyCharges_encoded'] = le.fit_transform(df['MonthlyCharges'])
df['TotalCharges_encoded'] = le.fit_transform(df['TotalCharges'])
df['Churn_encoded'] = le.fit_transform(df['Churn'])

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'TotlCharges', 'Churn_encoded', 'gender_encoded',
#        'SeniorCitizen_encoded', 'Partner_encoded', 'Dependents_encoded',
#        'tenure_encoded', 'PhoneService_encoded', 'MultipleLines_encoded',
#        'InternetService_encoded', 'OnlineSecurity_encoded',
#        'TechSupport_encoded', 'StreamingTV_encoded', 'StreamingMovies_encoded',
#        'Contract_encoded', 'PaperlessBilling_encoded', 'PaymentMethod_encoded',
#        'MonthlyCharges_encoded', 'TotalCharges_encoded'],
#       dtype='object')

# %%
df2=df.drop(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn','MonthlyCharges_encoded', 'TotalCharges_encoded'],axis=1)

# %%
df2
# Out:
#       TotlCharges  Churn_encoded  gender_encoded  SeniorCitizen_encoded  \
# 0           29.85              0               0                      0
# 1         1889.50              0               1                      0
# 2          108.15              1               1                      0
# 3         1840.75              0               1                      0
# 4          151.65              1               0                      0
# ...           ...            ...             ...                    ...
# 7038      1990.50              0               1                      0
# 7039      7362.90              0               0                      0
# 7040       346.45              0               0                      0
# 7041       306.60              1               1                      1
# 7042      6844.50              0               1                      0
#
#       Partner_encoded  Dependents_encoded  tenure_encoded  \
# ...

# %%
df2.corr()
# Out:
#                           TotlCharges  Churn_encoded  gender_encoded  \
# TotlCharges                  1.000000      -0.198324       -0.000080
# Churn_encoded               -0.198324       1.000000       -0.008612
# gender_encoded              -0.000080      -0.008612        1.000000
# SeniorCitizen_encoded        0.103006       0.150889       -0.001874
# Partner_encoded              0.317504      -0.150448       -0.001808
# Dependents_encoded           0.062078      -0.164221        0.010517
# tenure_encoded               0.826178      -0.352229        0.005106
# PhoneService_encoded         0.113214       0.011942       -0.006488
# MultipleLines_encoded        0.452577       0.038037       -0.006739
# InternetService_encoded     -0.175755      -0.047291       -0.000863
# OnlineSecurity_encoded       0.253224      -0.289309       -0.015017
# TechSupport_encoded          0.275625      -0.282492       -0.006825
# StreamingTV_encoded          0.391470      -0.036581       -0.006421
# ...

# %%
plt.figure(figsize=(20,18))
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >
